# %% [markdown]
# # TODO 14 Stabilization – Reflexion Study\n\nThis notebook compares baseline (no Reflexion memory) with the new loop controller and template service.\n- SID: _fill when running_\n- Model: refer to `plan.json` (`model_version`).\n- Prompt hash: see `metadata/<SID>/plan.json`.\n\nRefer to `docs/experiments/README.md` for logging/export rules.

# %%
import json\nfrom pathlib import Path\n\nSID = "sid-placeholder"\nmetadata_dir = Path("metadata") / SID\nloop_state = json.loads((metadata_dir / "loop_state.json").read_text()) if (metadata_dir / "loop_state.json").exists() else {}\nreflexion_store = Path("rag/memories/reflexion_store.jsonl")\nprint("Loop state:", loop_state)\nif reflexion_store.exists():\n    lines = reflexion_store.read_text().strip().splitlines()[-3:]\n    print("Recent Reflexion entries:")\n    for line in lines:\n        print(line)
